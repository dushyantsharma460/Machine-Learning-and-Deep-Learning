# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("housing.csv")

# %%
df['income_category'] = pd.cut(df['median_income'], bins = [0, 1.5, 3.0, 4.5, 6.0, np.inf], labels = [1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df, df['income_category']):     # df['income_category'] = the column to use for stratification
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 17352    -120.42     34.89                24.0       2020.0           307.0
# 3505     -118.45     34.25                36.0       1453.0           270.0
# 7777     -118.10     33.91                35.0       1653.0           325.0
# 14155    -117.07     32.77                38.0       3779.0           614.0
# ...          ...       ...                 ...          ...             ...
# 12182    -117.29     33.72                19.0       2248.0           427.0
# 7275     -118.24     33.99                33.0        885.0           294.0
# 17223    -119.72     34.44                43.0       1781.0           342.0
# 10786    -117.91     33.63                30.0       2071.0           412.0
# 3965     -118.56     34.19                36.0       2600.0           441.0
#
# ...

# %%
# Lets remove the income cat column 
for sett in (strat_train_set, strat_test_set):
    sett.drop("income_category", axis=1, inplace=True)

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
# Now we will do all the visualization only on the train data set we will not touch the test data set
# Make a copy of train data set we will do all the things on copy dataset

dft = strat_train_set.copy()

# %%
dft.plot(kind="scatter", x="latitude", y="longitude", grid=True)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# We will also adjust alpha to see the higher density of houses

dft.plot(kind="scatter", x="latitude", y="longitude", grid=True, alpha=0.3)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
dft.plot(kind="scatter", x="latitude", y="longitude", grid=True, cmap="jet", c="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
df.drop(labels="ocean_proximity", inplace=True, axis=1)
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# income_category     -0.010690 -0.085528           -0.146920     0.220528
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# ...

# %%
from pandas.plotting import scatter_matrix
attributes = ["housing_median_age", "median_income", "median_house_value"]
scatter_matrix(df[attributes], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='housing_median_age', ylabel='housing_median_age'>,
#         <Axes: xlabel='median_income', ylabel='housing_median_age'>,
#         <Axes: xlabel='median_house_value', ylabel='housing_median_age'>],
#        [<Axes: xlabel='housing_median_age', ylabel='median_income'>,
#         <Axes: xlabel='median_income', ylabel='median_income'>,
#         <Axes: xlabel='median_house_value', ylabel='median_income'>],
#        [<Axes: xlabel='housing_median_age', ylabel='median_house_value'>,
#         <Axes: xlabel='median_income', ylabel='median_house_value'>,
#         <Axes: xlabel='median_house_value', ylabel='median_house_value'>]],
#       dtype=object)
